# %% [markdown]
# # Solar Energy Potential in Berlin
#
# In this notebook, we calculate the solar energy potential for Berlin.

# %%
import matplotlib.pyplot as plt
from sabzenergy.climate import create_cutout
from sabzenergy.solar import calculate_solar_potential

plt.style.use("ggplot")

# %%
CITY = "Berlin"
YEAR = 2023

# cutout = create_cutout(CITY, YEAR, output_dir="../data")

# %%
# pv_gen = calculate_solar_potential(cutout, panel="CSi")
# pv_gen.sum("x").sum("y").plot()
# plt.title("Solar Power Generation in Berlin")
# plt.show()
