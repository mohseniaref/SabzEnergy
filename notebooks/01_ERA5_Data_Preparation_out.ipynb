# %% [markdown]
# # ERA5 Data Preparation
#
# This notebook shows how to download ERA5 data using `atlite` for our target cities.

# %%
import os
from sabzenergy.climate import create_cutout
from sabzenergy.utils.locations import CITIES

# Ensure you have your CDS API key set up (e.g., in ~/.cdsapirc)
# Out:
# /home/mohammad/.local/lib/python3.8/site-packages/geopandas/_compat.py:124: UserWarning: The Shapely GEOS version (3.11.4-CAPI-1.17.4) is incompatible with the GEOS version PyGEOS was compiled with (3.10.3-CAPI-1.16.1). Conversions between both will be slow.
#   warnings.warn(
# /home/mohammad/anaconda3/envs/code/lib/python3.8/site-packages/OpenSSL/SSL.py:16: CryptographyDeprecationWarning: Python 3.8 is no longer supported by the Python core team and support for it is deprecated in cryptography. The next release of cryptography will remove support for Python 3.8.
#   from cryptography import x509

# %%
YEAR = 2023
CITY = "Berlin"

print(f"Creating cutout for {CITY}...")
# Uncomment the line below to actually download data (may take a while)
# cutout = create_cutout(CITY, YEAR, output_dir="../data")
# print(cutout)
# Out:
# Creating cutout for Berlin...
