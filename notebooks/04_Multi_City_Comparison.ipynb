# %% [markdown]
# # Multi-City Comparison
#
# Compare the potential across Berlin, Hamburg, Münster, and München.

# %%
from sabzenergy.utils.locations import CITIES

print("Cities available for analysis:")
print(list(CITIES.keys()))

# %%
# You can loop over CITIES and plot the annual sum for each to compare.
